# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/NBA/index.html'

r=requests.get(url)
soup=BeautifulSoup(r.text,'html5lib')

for d in soup.find_all(class_='title'):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        for i in r.find_all(class_='article-meta-value'):
            print(i.text)
    except:
        continue
# Out:
# Muma5566 (木馬56)
# NBA
# [新聞] Tatum:會努力幫助球隊贏球，自己也想入選全明星
# Wed Dec 11 13:40:59 2019
# TheBatman (蝙蝠俠)
# NBA
# [花邊] Nelson談論當年Howard在魔術的"魔獸人生"
# Wed Dec 11 13:52:04 2019
# LinBaoYan (負酬者聯盟)
# NBA
# [新聞] 卡特第1500場出賽 史上第5人
# Wed Dec 11 13:55:41 2019
# thnlkj0665 (灰色地帶)
# NBA
# [花邊] 厄文持續缺賽 錯失激勵獎金12.5萬美元
# Wed Dec 11 14:38:00 2019
# kairiyu (E N O U G H  is  enough)
# NBA
# [花邊] 當湖人主場播放歌手Lizzo歌曲時，本人在場邊直接表演露臀舞
# Wed Dec 11 14:59:16 2019
# innocent8675 (坤溪戴維斯)
# NBA
# [花邊]
# Wed Dec 11 14:59:57 2019
# NSYSUheng (Madara)
# NBA
# [花邊] KD重申了自己想要擁有一支NBA球隊的願望
# Wed Dec 11 15:39:17 2019
# tmac4ever ()
# NBA
# Re: [花邊] Jimmy Butler的instagram貼文
# Wed Dec 11 16:21:42 2019
# Israfil (贖罪聖音)
# NBA
# [新聞] 三分砲火猛烈 伯坦斯：籃框實在太寬了
# Wed Dec 11 16:56:49 2019
# thnlkj0665 (灰色地帶)
# NBA
# [情報] New Balance為Kawhi架設看板感謝多倫多
# Wed Dec 11 17:39:27 2019
# lovea (lovea)
# NBA
# [花邊] Tacko Fall：KG是傳奇，見到他對我意義
# Wed Dec 11 17:54:26 2019
# Darren2012 (達倫)
# NBA
# [討論] 08年京奧男籃的西班牙很謎嗎?
# Wed Dec 11 19:33:05 2019
# pneumo (超☆冒險蓋)
# NBA
# [討論] LBJ在投三分球之前的準備動作
# Wed Dec 11 20:50:32 2019
# whoAU (你是誰？)
# NBA
# [情報] 全能後衛！Ish Smith在暫停時幫忙拖地
# Wed Dec 11 20:59:53 2019
# LinBaoYan (負酬者聯盟)
# NBA
# [花邊] 前賽爾提克球員因未尊重中國國歌遭罰款
# Wed Dec 11 21:28:45 2019
# s27052705 (小飽)
# NBA
# [花邊] 舞王賽後發聲：跟隨我
# Wed Dec 11 22:00:02 2019
# Vedan (味丹)
# NBA
# [公告] 樂透取消及未來不再開啟樂透
# Mon Jun 24 15:08:02 2019
# qazwsx879345 (Rajon Rondo)
# NBA
# [公告] 版主上任相關事項
# Fri Oct 25 10:44:03 2019
# JerroLi (銀色小刀)
# NBA
# [情報] SEASON Schedule 賽程 December 19–20
# Fri Nov 29 00:46:01 2019
# dragon803 (好想去露營啊~)
# NBA
# [公告]是否禁止basketball top 5文章投票開始
# Sun Dec  8 23:55:00 2019

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/NBA/index1.html'

r=requests.get(url)
soup=BeautifulSoup(r.text,'html5lib')

for d in soup.find_all(class_='title'):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        for i in r.find_all(class_='article-meta-value'):
            print(i.text)
    except:
        continue
# Out:
# Price (Price)
# NBA
# [轉錄]Lyotard 對於太陽板討論串的結論
# Sun May 16 01:54:33 2004
# Price (Price)
# NBA
# [公告] 請停止一切關於本次活動的發言
# Mon May 24 00:43:00 2004
# Frankaze (神采風華)
# NBA
# [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# Tue Jun  8 01:16:45 2004
# Frankaze (神采風華)
# NBA
# [轉錄]再轉一篇好文來
# Tue Jun  8 09:02:23 2004
# Price (Price)
# NBA
# [轉錄][情報] 夏洛特山貓系列
# Thu Jun 10 00:39:35 2004
# Price (Price)
# NBA
# [轉錄]Re: [心得] 真是受不了糗爺....
# Thu Jun 10 00:51:35 2004
# Price (Price)
# NBA
# [轉錄]總冠軍賽NO.2觀後感
# Thu Jun 10 12:05:07 2004
# AmuroNamie (原來太嗨真的會失眠^___^)
# NBA
# [心得] Rasheed Wallace
# Fri Jun 11 15:06:09 2004
# toptree (  )
# NBA
# 掌控球賽的男人
# Sat Jun 12 07:13:04 2004
# skchang (3EB板開板囉！)
# NBA
# [閒聊] 說說2004季後賽名場面回顧
# Sat Jun 12 13:21:49 2004
# shineup ()
# NBA
# [心得] 其實說穿了 就是活塞的防守太可怕了
# Sat Jun 12 13:12:47 2004
# cOvi (喵~)
# NBA
# Re: [閒聊] 說說2004季後賽名場面回顧
# Sat Jun 12 16:43:07 2004
# ykshih (￼N￼Ns)
# NBA
# Re: [閒聊] 說說2004季後賽名場面回顧
# Sat Jun 12 17:26:37 2004
# Frankaze (神采風華)
# NBA
# Re: [閒聊] 說說2004季後賽名場面回顧
# Sat Jun 12 18:34:46 2004
# Price (Price)
# NBA
# [轉錄]Re: 總冠軍賽NO.3觀後感
# Mon Jun 14 02:18:52 2004
# Frankaze (神采風華)
# NBA
# [轉錄]Re: 總冠軍賽NO.3觀後感
# Mon Jun 14 02:34:33 2004
# star1 (第一次魔術表演不算成功)
# NBA
# Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# Mon Jun 14 07:16:30 2004
# coldspring (笑笑)
# NBA
# Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# Mon Jun 14 09:24:57 2004
# airbear (地圖)
# NBA
# Re: Kobe is frustrated...
# Mon Jun 14 12:56:14 2004
# pennykidd (andre)
# NBA
# Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# Mon Jun 14 22:07:01 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/MLB/index.html'

r=requests.get(url)
soup=BeautifulSoup(r.text,'html5lib')

for d in soup.find_all(class_='title'):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        for i in r.find_all(class_='article-meta-value'):
            print(i.text)
    except:
        continue
# Out:
# youngluke (luke)
# MLB
# [情報] 2020 墨西哥系列賽 [email protected]
# Wed Dec 11 11:21:23 2019
# Wojnarowski (@wojespn)
# MLB
# [情報] Gerrit Cole to Yankees
# Wed Dec 11 12:58:05 2019
# McCormick (又被掛掉了)
# MLB
# [外電] Nomar Mazara被交易去白襪
# Wed Dec 11 13:23:10 2019
# ug945 (ug945)
# MLB
# Re: [情報] MLB 2019年度隊伍
# Wed Dec 11 13:25:49 2019
# McCormick (又被掛掉了)
# MLB
# Re: [情報] 太空人願意粉身碎骨搶下Cole
# Wed Dec 11 13:35:25 2019
# thnlkj0665 (灰色地帶)
# MLB
# [情報] 道奇隊鎖定 Madison Bumgarner
# Wed Dec 11 13:42:22 2019
# otaku32286 (宅人)
# MLB
# Fw: [閒聊]洋基簽下Cole的後續影響
# Wed Dec 11 15:51:06 2019
# rn940111 (自盡比較快)
# MLB
# [公告] MLB.tv for 2019 徵求區
# Sat Feb 16 16:03:14 2019
