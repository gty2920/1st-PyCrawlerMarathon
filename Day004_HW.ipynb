# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
#
# 型態差異

# %%
'''
Your Code
'''
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10973322494","type":"PushEvent","actor":{"id":51776310,"login":"TangBii","display_login":"TangBii","gravatar_id":"","url":"https://api.github.com/users/TangBii","avatar_url":"https://avatars.githubusercontent.com/u/51776310?"},"repo":{"id":224410445,"name":"TangBii/TangBii.github.io","url":"https://api.github.com/repos/TangBii/TangBii.github.io"},"payload":{"push_id":4334428067,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"869665295c975434b82805d44a2377f2a5db9fd8","before":"361ea82333e26c064f7e52ac544f0bcde6f390c2","commits":[{"sha":"869665295c975434b82805d44a2377f2a5db9fd8","author":{"email":"601098499@qq.com","name":"TangBii"},"message":"Site updated: 2019-11-29 13:19:47","distinct":true,"url":"https://api.github.com/repos/TangBii/TangBii.github.io/commits/869665295c975434b82805d44a2377f2a5db9fd8"}]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322490","type":"PushEvent","actor":{"id":25004868,"login":"const-k","display_login":"const-k","gravatar_id":"","url":"https://api.github.com/users/const-k","avatar_url":"https://avatars.githubusercontent.com/u/25004868?"},"repo":{"id":219404596,"name":"const-k/simple-maven-project-with-tests","url":"https://api.github.com/repos/const-k/simple-maven-project-with-tests"},"payload":{"push_id":4334428065,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a1507718d1263038112fcbb4c6870b6fba546a48","before":"b3a39b21ac048d9298986e0d4a1d9f4dd185df8f","commits":[{"sha":"a1507718d1263038112fcbb4c6870b6fba546a48","author":{"email":"kss07120@gmail.com","name":"const-k"},"message":"Update Jenkinsfile","distinct":true,"url":"https://api.github.com/repos/const-k/simple-maven-project-with-tests/commits/a1507718d1263038112fcbb4c6870b6fba546a48"}]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322485","type":"CreateEvent","actor":{"id":58320520,"login":"gageiscool","display_login":"gageiscool","gravatar_id":"","url":"https://api.github.com/users/gageiscool","avatar_url":"https://avatars.githubusercontent.com/u/58320520?"},"repo":{"id":224781819,"name":"gageiscool/Gage","url":"https://api.github.com/repos/gageiscool/Gage"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322486","type":"PushEvent","actor":{"id":56465314,"login":"Jack-genius","display_login":"Jack-genius","gravatar_id":"","url":"https://api.github.com/users/Jack-genius","avatar_url":"https://avatars.githubusercontent.com/u/56465314?"},"repo":{"id":215474703,"name":"Jack-genius/jack-genius.github.io","url":"https://api.github.com/repos/Jack-genius/jack-genius.github.io"},"payload":{"push_id":4334428063,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e4e914ab4ef8a5691abcb9a50b1111a59515e32d","before":"6f95fde96e2907c5947da05476386ef73f309b0f","commits":[{"sha":"e4e914ab4ef8a5691abcb9a50b1111a59515e32d","author":{"email":"56465314+Jack-genius@users.noreply.github.com","name":"Jack-genius"},"message":"Update 2019-10-15-排个座次？.md","distinct":true,"url":"https://api.github.com/repos/Jack-genius/jack-genius.github.io/commits/e4e914ab4ef8a5691abcb9a50b1111a59515e32d"}]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322487","type":"PushEvent","actor":{"id":25180681,"login":"renovate-bot","display_login":"renovate-bot","gravatar_id":"","url":"https://api.github.com/users/renovate-bot","avatar_url":"https://avatars.githubusercontent.com/u/25180681?"},"repo":{"id":211969970,"name":"renovate-bot/java-translate","url":"https://api.github.com/repos/renovate-bot/java-translate"},"payload":{"push_id":4334428055,"size":0,"distinct_size":0,"ref":"refs/heads/master","head":"4a30c3ebb72f447c13b9b4cbaf3ea4737a4844d3","before":"4a30c3ebb72f447c13b9b4cbaf3ea4737a4844d3","commits":[]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322482","type":"DeleteEvent","actor":{"id":8960313,"login":"halfopen","display_login":"halfopen ...

# %%
json.loads(r.text)
# Out:
# [{'id': '10973322494',
#   'type': 'PushEvent',
#   'actor': {'id': 51776310,
#    'login': 'TangBii',
#    'display_login': 'TangBii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TangBii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51776310?'},
#   'repo': {'id': 224410445,
#    'name': 'TangBii/TangBii.github.io',
#    'url': 'https://api.github.com/repos/TangBii/TangBii.github.io'},
#   'payload': {'push_id': 4334428067,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '869665295c975434b82805d44a2377f2a5db9fd8',
#    'before': '361ea82333e26c064f7e52ac544f0bcde6f390c2',
#    'commits': [{'sha': '869665295c975434b82805d44a2377f2a5db9fd8',
#      'author': {'email': '601098499@qq.com', 'name': 'TangBii'},
#      'message': 'Site updated: 2019-11-29 13:19:47',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TangBii/TangBii.github.io/commits/869665295c975434b82805d44a2377f2a5db9fd8'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322490',
#   'type': 'PushEvent',
#   'actor': {'id': 25004868,
#    'login': 'const-k',
#    'display_login': 'const-k',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/const-k',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25004868?'},
#   'repo': {'id': 219404596,
#    'name': 'const-k/simple-maven-project-with-tests',
#    'url': 'https://api.github.com/repos/const-k/simple-maven-project-with-tests'},
#   'payload': {'push_id': 4334428065,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a1507718d1263038112fcbb4c6870b6fba546a48',
#    'before': 'b3a39b21ac048d9298986e0d4a1d9f4dd185df8f',
#    'commits': [{'sha': 'a1507718d1263038112fcbb4c6870b6fba546a48',
#      'author': {'email': 'kss07120@gmail.com', 'name': 'const-k'},
#      'message': 'Update Jenkinsfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/const-k/simple-maven-project-with-tests/commits/a1507718d1263038112fcbb4c6870b6fba546a48'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322485',
#   'type': 'CreateEvent',
#   'actor': {'id': 58320520,
#    'login': 'gageiscool',
#    'display_login': 'gageiscool',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gageiscool',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58320520?'},
#   'repo': {'id': 224781819,
#    'name': 'gageiscool/Gage',
#    'url': 'https://api.github.com/repos/gageiscool/Gage'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322486',
#   'type': 'PushEvent',
#   'actor': {'id': 56465314,
#    'login': 'Jack-genius',
#    'display_login': 'Jack-genius',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jack-genius',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56465314?'},
#   'repo': {'id': 215474703,
#    'name': 'Jack-genius/jack-genius.github.io',
#    'url': 'https://api.github.com/repos/Jack-genius/jack-genius.github.io'},
#   'payload': {'push_id': 4334428063,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e4e914ab4ef8a5691abcb9a50b1111a59515e32d',
#    'before': '6f95fde96e2907c5947da05476386ef73f309b0f',
#    'commits': [{'sha': 'e4e914ab4ef8a5691abcb9a50b1111a59515e32d',
#      'author': {'email': '56465314+Jack-genius@users.noreply.github.com',
#       'name': 'Jack-genius'},
#      'message': 'Update 2019-10-15-排个座次？.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jack-genius/jack-genius.github.io/commits/e4e914ab4ef8a5691abcb9a50b1111a59515e32d'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322487',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 211969970,
#    'name': 'renovate-bot/java-translate',
#    'url': 'https://api.github.com/repos/renovate-bot/java-translate'},
#   'payload': {'push_id': 4334428055,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '4a30c3ebb72f447c13b9b4cbaf3ea4737a4844d3',
#    'before': '4a30c3ebb72f447c13b9b4cbaf3ea4737a4844d3',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322482',
#   'type': 'DeleteEvent',
#   'actor': {'id': 8960313,
#    'login': 'halfopen',
#    'display_login': 'halfopen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/halfopen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8960313?'},
#   'repo': {'id': 204376520,
#    'name': 'halfopen/GraduationThesis',
#    'url': 'https://api.github.com/repos/halfopen/GraduationThesis'},
#   'payload': {'ref': 'overleaf-2019-11-29-0519',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322481',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 224779548,
#    'name': 'Taifendesune/Sudyplatform',
#    'url': 'https://api.github.com/repos/Taifendesune/Sudyplatform'},
#   'payload': {'ref': 'dependabot/maven/com.alibaba-fastjson-1.2.25',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '666',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322468',
#   'type': 'PushEvent',
#   'actor': {'id': 58280240,
#    'login': 'FBROTHE534studentglendaleedu',
#    'display_login': 'FBROTHE534studentglendaleedu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FBROTHE534studentglendaleedu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58280240?'},
#   'repo': {'id': 224559843,
#    'name': 'FBROTHE534studentglendaleedu/Roo.GoogleToken.Public',
#    'url': 'https://api.github.com/repos/FBROTHE534studentglendaleedu/Roo.GoogleToken.Public'},
#   'payload': {'push_id': 4334428052,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cdafa6b14e5f95ef80925d6854511755e9b8e61d',
#    'before': 'a26be713501329f20c9a24fd9859df871e712bf6',
#    'commits': [{'sha': 'cdafa6b14e5f95ef80925d6854511755e9b8e61d',
#      'author': {'email': '58280240+FBROTHE534studentglendaleedu@users.noreply.github.com',
#       'name': 'FBROTHE534studentglendaleedu'},
#      'message': '{"Creator":"fbrothe534@student.glendale.edu"}',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FBROTHE534studentglendaleedu/Roo.GoogleToken.Public/commits/cdafa6b14e5f95ef80925d6854511755e9b8e61d'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322467',
#   'type': 'PushEvent',
#   'actor': {'id': 51372520,
#    'login': 'saurabhchardereal',
#    'display_login': 'saurabhchardereal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saurabhchardereal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51372520?'},
#   'repo': {'id': 224636457,
#    'name': 'saurabhchardereal/device_asus_X00T',
#    'url': 'https://api.github.com/repos/saurabhchardereal/device_asus_X00T'},
#   'payload': {'push_id': 4334428054,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/havoc',
#    'head': 'f741890cae70aa0ddb960faae4878647d3371b01',
#    'before': '5e1919dbc2770a317ac8c687728fa28b90151742',
#    'commits': [{'sha': '61b7851fd19f8b23da3cf2bce5c6bcac7c69fddc',
#      'author': {'email': 'xtrymind@gmail.com', 'name': 'Dede Dindin Qudsy'},
#      'message': "X00T: disable cdsprcd\n\nX00T doesn't have cdsprcd, so disable this\n\nSigned-off-by: Dede Dindin Qudsy <xtrymind@gmail.com>",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/saurabhchardereal/device_asus_X00T/commits/61b7851fd19f8b23da3cf2bce5c6bcac7c69fddc'},
#     {'sha': 'f741890cae70aa0ddb960faae4878647d3371b01',
#      'author': {'email': 'gwolf2u.website@gmail.com', 'name': 'Lup Gabriel'},
#      'message': 'X00T: overlay: Allow auto-brightness in doze mode\n\nChange-Id: I7968e05fb37f4f2b0c10bd62c6dfb7695aeb5109\n\nSigned-off-by: Lup Gabriel <gwolf2u.website@gmail.com>\nSigned-of-by: Saurabh Charde <saurabhchardereal@gmail.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/saurabhchardereal/device_asus_X00T/commits/f741890cae70aa0ddb960faae4878647d3371b01'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322461',
#   'type': 'PushEvent',
#   'actor': {'id': 28216801,
#    'login': 'redpanda3',
#    'display_login': 'redpanda3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/redpanda3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28216801?'},
#   'repo': {'id': 153868970,
#    'name': 'redpanda3/soDLA',
#    'url': 'https://api.github.com/repos/redpanda3/soDLA'},
#   'payload': {'push_id': 4334428051,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8bf127729167ef22f711f8aa7913d757245ab6c4',
#    'before': 'd486ec1aa7a762f6d3dbb4d299a9e841c8918ddd',
#    'commits': [{'sha': '8bf127729167ef22f711f8aa7913d757245ab6c4',
#      'author': {'email': 'yuda@berkeley.edu', 'name': 'redpanda3'},
#      'message': 'Update NV_NVDLA_sdp.scala',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/redpanda3/soDLA/commits/8bf127729167ef22f711f8aa7913d757245ab6c4'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322462',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 216061773,
#    'name': 'renovate-bot/java-websecurityscanner',
#    'url': 'https://api.github.com/repos/renovate-bot/java-websecurityscanner'},
#   'payload': {'push_id': 4334428047,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': 'c7deaccc24de99c00bee5bf290d566b46cb42c77',
#    'before': 'c7deaccc24de99c00bee5bf290d566b46cb42c77',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322463',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 66828339,
#    'name': 'ontohub/ontohub-backend',
#    'url': 'https://api.github.com/repos/ontohub/ontohub-backend'},
#   'payload': {'ref': 'dependabot/bundler/rubocop-0.76.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z',
#   'org': {'id': 1575984,
#    'login': 'ontohub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ontohub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1575984?'}},
#  {'id': '10973322460',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 180464025,
#    'name': 'renovate-bot/js-green-licenses',
#    'url': 'https://api.github.com/repos/renovate-bot/js-green-licenses'},
#   'payload': {'push_id': 4334428044,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '25d0235d0ff996b644fe84482241bda5a4b14b2a',
#    'before': '25d0235d0ff996b644fe84482241bda5a4b14b2a',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322459',
#   'type': 'CreateEvent',
#   'actor': {'id': 52701329,
#    'login': 'maroua-briki',
#    'display_login': 'maroua-briki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/maroua-briki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52701329?'},
#   'repo': {'id': 224781815,
#    'name': 'maroua-briki/Application-Web-Django',
#    'url': 'https://api.github.com/repos/maroua-briki/Application-Web-Django'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'plateforme de test en ligne ',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:53Z'},
#  {'id': '10973322443',
#   'type': 'PushEvent',
#   'actor': {'id': 58317269,
#    'login': 'Jessy198',
#    'display_login': 'Jessy198',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jessy198',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58317269?'},
#   'repo': {'id': 224763538,
#    'name': 'Jessy198/Too-much-horny-now',
#    'url': 'https://api.github.com/repos/Jessy198/Too-much-horny-now'},
#   'payload': {'push_id': 4334428034,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f1d794513022dc836e62a2bcd7b5a7fbd77e143a',
#    'before': 'd3549c9f0a82ec09e026ff5e2ed418247dae131e',
#    'commits': [{'sha': 'f1d794513022dc836e62a2bcd7b5a7fbd77e143a',
#      'author': {'email': '58317269+Jessy198@users.noreply.github.com',
#       'name': 'Jessy198'},
#      'message': 'Add files via upload\n\nHi.I am Jessy. WE SHOULD FUCK. Like right now, right here. Hard, fast. Pin me down, kiss me hard, look me in the eyes and fuck me\r\nlike you’ve never fucked someone before.contact me here : http://zpr.io/tYb3k\r\nI want youHi.I am Jessy. WE SHOULD FUCK. Like right now, right here. Hard, fast. Pin me down, kiss me hard, look me in the eyes and fuck me\r\nlike you’ve never fucked someone before.contact me here : http://zpr.io/tYb3k\r\nI want you, all of you. I want to feel you inside me, deep inside me. I want you to tell me when you’re going to cum, hear you moan\r\nmy name and fuck me harder.Just go here http://zpr.io/tYb3k and verify your email and message me with my username : Jessy22\r\nAnd I am yours.Waiting for sexiest moment, all of you. I want to feel you inside me, deep inside me. I want you to tell me when you’re going to cum, hear you moan\r\nmy name and fuck me harder.Just go here http://zpr.io/tYb3k and verify your email and message me with my username : Jessy22\r\nAnd I am yours.Waiting for sexiest moment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jessy198/Too-much-horny-now/commits/f1d794513022dc836e62a2bcd7b5a7fbd77e143a'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322434',
#   'type': 'PushEvent',
#   'actor': {'id': 40892157,
#    'login': 'pbaffiliate25',
#    'display_login': 'pbaffiliate25',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pbaffiliate25',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40892157?'},
#   'repo': {'id': 224781707,
#    'name': 'pbaffiliate25/testRepo00487680',
#    'url': 'https://api.github.com/repos/pbaffiliate25/testRepo00487680'},
#   'payload': {'push_id': 4334428037,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f7778296790985012075fc7237a8f2d1bd100b0e',
#    'before': '02561de5f4bc285fb649b8feb01032f3037fbe64',
#    'commits': [{'sha': 'f7778296790985012075fc7237a8f2d1bd100b0e',
#      'author': {'email': '40892157+pbaffiliate25@users.noreply.github.com',
#       'name': 'pbaffiliate25'},
#      'message': 'This is to test the path with left slash',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pbaffiliate25/testRepo00487680/commits/f7778296790985012075fc7237a8f2d1bd100b0e'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322438',
#   'type': 'PushEvent',
#   'actor': {'id': 20026994,
#    'login': 'wicever',
#    'display_login': 'wicever',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wicever',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20026994?'},
#   'repo': {'id': 179852571,
#    'name': 'wicever/res',
#    'url': 'https://api.github.com/repos/wicever/res'},
#   'payload': {'push_id': 4334428035,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '04f15c04c368d588d08d53db1f321e217cf4ff1c',
#    'before': 'f25956e0b3260080c6fa55eac800797f0d2ea227',
#    'commits': [{'sha': '04f15c04c368d588d08d53db1f321e217cf4ff1c',
#      'author': {'email': 'hi.songjw@foxmail.com', 'name': 'ven'},
#      'message': 'Upload by PicGo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wicever/res/commits/04f15c04c368d588d08d53db1f321e217cf4ff1c'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322440',
#   'type': 'PushEvent',
#   'actor': {'id': 45385104,
#    'login': 'nywxy',
#    'display_login': 'nywxy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nywxy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45385104?'},
#   'repo': {'id': 224537297,
#    'name': 'nywxy/LuckyNumber',
#    'url': 'https://api.github.com/repos/nywxy/LuckyNumber'},
#   'payload': {'push_id': 4334428040,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7205f7957f4362ea4721dab7b4f1c435a0848c8d',
#    'before': 'e6567bad98e6c0dbcd364a7d48960c378611cf60',
#    'commits': [{'sha': '7205f7957f4362ea4721dab7b4f1c435a0848c8d',
#      'author': {'email': '150626630@qq.com', 'name': 'nywxy'},
#      'message': 'ui',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nywxy/LuckyNumber/commits/7205f7957f4362ea4721dab7b4f1c435a0848c8d'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322421',
#   'type': 'PushEvent',
#   'actor': {'id': 10625444,
#    'login': 'christinezuzart',
#    'display_login': 'christinezuzart',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/christinezuzart',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10625444?'},
#   'repo': {'id': 220896041,
#    'name': 'christinezuzart/DeepLearning',
#    'url': 'https://api.github.com/repos/christinezuzart/DeepLearning'},
#   'payload': {'push_id': 4334428024,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bd5239b108250e00664449cf2134f5247b28ffff',
#    'before': 'f1e7e4060e41fcf61d81f20e56b5bcaf8248308c',
#    'commits': [{'sha': 'bd5239b108250e00664449cf2134f5247b28ffff',
#      'author': {'email': 'christinezuzart@gmail.com',
#       'name': 'christinezuzart'},
#      'message': 'Created using Colaboratory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/christinezuzart/DeepLearning/commits/bd5239b108250e00664449cf2134f5247b28ffff'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322425',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 198907990,
#    'name': 'renovate-bot/nodejs-asset',
#    'url': 'https://api.github.com/repos/renovate-bot/nodejs-asset'},
#   'payload': {'push_id': 4334428028,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': 'a321df601656e3c9dbff95c9921fcd5f66508d91',
#    'before': 'a321df601656e3c9dbff95c9921fcd5f66508d91',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322424',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 224780937,
#    'name': 'IslaBecker91031015/NodeJSAPI',
#    'url': 'https://api.github.com/repos/IslaBecker91031015/NodeJSAPI'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/mongoose-5.7.5',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322414',
#   'type': 'PushEvent',
#   'actor': {'id': 1157344,
#    'login': 'shogo82148',
#    'display_login': 'shogo82148',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shogo82148',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1157344?'},
#   'repo': {'id': 179654247,
#    'name': 'shogo82148/codebuild-golang',
#    'url': 'https://api.github.com/repos/shogo82148/codebuild-golang'},
#   'payload': {'push_id': 4334428025,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/stop-building-go1.11',
#    'head': 'b97330570776c517497af2be04971a999a99ec04',
#    'before': 'd60bb88cce53ef5f59b8572d3ab715563cb87e08',
#    'commits': [{'sha': 'b97330570776c517497af2be04971a999a99ec04',
#      'author': {'email': 'shogo82148@gmail.com', 'name': 'Ichinose Shogo'},
#      'message': 'remove Go 1.11 from README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shogo82148/codebuild-golang/commits/b97330570776c517497af2be04971a999a99ec04'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322396',
#   'type': 'PushEvent',
#   'actor': {'id': 20680635,
#    'login': 'HandsomeTea',
#    'display_login': 'HandsomeTea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HandsomeTea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20680635?'},
#   'repo': {'id': 214143709,
#    'name': 'HandsomeTea/web-admin-server',
#    'url': 'https://api.github.com/repos/HandsomeTea/web-admin-server'},
#   'payload': {'push_id': 4334428009,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '6abf13a10ee26528c7cadafa671bb6ce29e0e40f',
#    'before': '4c49774b50e21aa42442d64220b7672b2fcdfbbc',
#    'commits': [{'sha': '4b55d7de1ea923b6a9c13888cef31c9708769b23',
#      'author': {'email': 'haifeng_liu@bizconf.cn', 'name': 'haifeng_liu'},
#      'message': 'code update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HandsomeTea/web-admin-server/commits/4b55d7de1ea923b6a9c13888cef31c9708769b23'},
#     {'sha': '6abf13a10ee26528c7cadafa671bb6ce29e0e40f',
#      'author': {'email': 'haifeng_liu@bizconf.cn', 'name': 'haifeng_liu'},
#      'message': 'code update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HandsomeTea/web-admin-server/commits/6abf13a10ee26528c7cadafa671bb6ce29e0e40f'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322398',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 66828339,
#    'name': 'ontohub/ontohub-backend',
#    'url': 'https://api.github.com/repos/ontohub/ontohub-backend'},
#   'payload': {'action': 'closed',
#    'number': 560,
#    'pull_request': {'url': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/560',
#     'id': 333439406,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzMzNDM5NDA2',
#     'html_url': 'https://github.com/ontohub/ontohub-backend/pull/560',
#     'diff_url': 'https://github.com/ontohub/ontohub-backend/pull/560.diff',
#     'patch_url': 'https://github.com/ontohub/ontohub-backend/pull/560.patch',
#     'issue_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/560',
#     'number': 560,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump rubocop from 0.58.2 to 0.76.0',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [rubocop](https://github.com/rubocop-hq/rubocop) from 0.58.2 to 0.76.0.\n<details>\n<summary>Release notes</summary>\n\n*Sourced from [rubocop\'s releases](https://github.com/rubocop-hq/rubocop/releases).*\n\n> ## RuboCop 0.76\n> ### Bug fixes\r\n> \r\n> * [#7439](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7439): Make `Style/FormatStringToken` ignore percent escapes (`%%`). ([@&#8203;buehmann][])\r\n> * [#7438](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7438): Fix assignment edge-cases in `Layout/MultilineAssignmentLayout`. ([@&#8203;gsamokovarov][])\r\n> * [#7449](https://github-redirect.dependabot.com/rubocop-hq/rubocop/pull/7449): Make `Style/IfUnlessModifier` respect `rubocop:disable` comments for `Metrics/LineLength`. ([@&#8203;jonas054][])\r\n> * [#7442](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7442): Fix an incorrect autocorrect for `Style/SafeNavigation` when an object check followed by a method call with a comment at EOL. ([@&#8203;koic][])\r\n> * [#7434](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7434): Fix an incorrect autocorrect for `Style/MultilineWhenThen` when the body of `when` branch starts with `then`. ([@&#8203;koic][])\r\n> * [#7464](https://github-redirect.dependabot.com/rubocop-hq/rubocop/pull/7464): Let `Performance/StartWith` and `Performance/EndWith` correct regexes that contain forward slashes. ([@&#8203;eugeneius][])\r\n> \r\n> ### Changes\r\n> \r\n> * [#7465](https://github-redirect.dependabot.com/rubocop-hq/rubocop/pull/7465): Add `os` to allowed names of `Naming/UncommunicativeMethodParamName` cop in default config. ([@&#8203;nijikon][])\r\n> * [#7446](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7446): Add `merge` to list of non-mutating methods. ([@&#8203;cstyles][])\r\n> * [#7077](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7077): **(Breaking)** Rename `Unneeded*` cops to `Redundant*` (e.g., `Style/UnneededPercentQ` becomes `Style/RedundantPercentQ`). ([@&#8203;scottmatthewman][])\r\n> * [#7396](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7396): Display assignments, branches, and conditions values with the offense. ([@&#8203;avmnu-sng][])\r\n> \r\n> [@&#8203;buehmann]: https://github.com/buehmann\r\n> [@&#8203;gsamokovarov]: https://github.com/gsamokovarov\r\n> [@&#8203;jonas054]: https://github.com/jonas054\r\n> [@&#8203;koic]: https://github.com/koic\r\n> [@&#8203;eugeneius]: https://github.com/eugeneius\r\n> [@&#8203;nijikon]: https://github.com/nijikon\r\n> [@&#8203;cstyles]: https://github.com/cstyles\r\n> [@&#8203;scottmatthewman]: https://github.com/scottmatthewman\r\n> [@&#8203;avmnu-sng]: https://github.com/avmnu-sng\r\n> \n> ## RuboCop 0.75.1\n> ### Bug fixes\r\n> \r\n> * [#7391](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7391): Support pacman formatter on Windows. ([@&#8203;laurenball][])\r\n> * [#7407](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7407): Make `Style/FormatStringToken` work inside hashes. ([@&#8203;buehmann][])\r\n> * [#7389](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7389): Fix an issue where passing a formatter might result in an error depending on what character it started with. ([@&#8203;jfhinchcliffe][])\r\n> * [#7397](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7397): Fix extra comments being added to the correction of `Style/SafeNavigation`. ([@&#8203;rrosenblum][])\r\n> * [#7378](https://github-redirect.dependabot.com/rubocop-hq/rubocop/pull/7378): Fix heredoc edge cases in `Layout/EmptyLineAfterGuardClause`. ([@&#8203;gsamokovarov][])\r\n> * [#7404](https://github-redirect.dependabot.com/rubocop-hq/rubocop/issues/7404): Fix a false negative for `Layout/IndentAssignment` when multiple assignment with line breaks on each line. ([@&#8203;koic][])\r\n> \r\n> ### Changes\r\n> \r\n> * [#7410](https://github-redir ...
#     'created_at': '2019-10-29T05:25:13Z',
#     'updated_at': '2019-11-29T05:19:51Z',
#     'closed_at': '2019-11-29T05:19:51Z',
#     'merged_at': None,
#     'merge_commit_sha': '239cbb66997aa0d75801e241161ba9c019a3665f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 693206330,
#       'node_id': 'MDU6TGFiZWw2OTMyMDYzMzA=',
#       'url': 'https://api.github.com/repos/ontohub/ontohub-backend/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0025ff',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/560/commits',
#     'review_comments_url': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/560/comments',
#     'review_comment_url': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/560/comments',
#     'statuses_url': 'https://api.github.com/repos/ontohub/ontohub-backend/statuses/91151abebd6a321fb71b2fd039cebd9e1635e504',
#     'head': {'label': 'ontohub:dependabot/bundler/rubocop-0.76.0',
#      'ref': 'dependabot/bundler/rubocop-0.76.0',
#      'sha': '91151abebd6a321fb71b2fd039cebd9e1635e504',
#      'user': {'login': 'ontohub',
#       'id': 1575984,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1NzU5ODQ=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1575984?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ontohub',
#       'html_url': 'https://github.com/ontohub',
#       'followers_url': 'https://api.github.com/users/ontohub/followers',
#       'following_url': 'https://api.github.com/users/ontohub/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ontohub/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ontohub/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ontohub/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ontohub/orgs',
#       'repos_url': 'https://api.github.com/users/ontohub/repos',
#       'events_url': 'https://api.github.com/users/ontohub/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ontohub/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 66828339,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2NjgyODMzOQ==',
#       'name': 'ontohub-backend',
#       'full_name': 'ontohub/ontohub-backend',
#       'private': False,
#       'owner': {'login': 'ontohub',
#        'id': 1575984,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1NzU5ODQ=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/1575984?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ontohub',
#        'html_url': 'https://github.com/ontohub',
#        'followers_url': 'https://api.github.com/users/ontohub/followers',
#        'following_url': 'https://api.github.com/users/ontohub/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ontohub/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ontohub/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ontohub/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ontohub/orgs',
#        'repos_url': 'https://api.github.com/users/ontohub/repos',
#        'events_url': 'https://api.github.com/users/ontohub/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ontohub/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ontohub/ontohub-backend',
#       'description': 'The main Ontohub service that serves the data for the frontend and other clients via the GraphQL API.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ontohub/ontohub-backend',
#       'forks_url': 'https://api.github.com/repos/ontohub/ontohub-backend/forks',
#       'keys_url': 'https://api.github.com/repos/ontohub/ontohub-backend/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ontohub/ontohub-backend/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ontohub/ontohub-backend/teams',
#       'hooks_url': 'https://api.github.com/repos/ontohub/ontohub-backend/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ontohub/ontohub-backend/events',
#       'assignees_url': 'https://api.github.com/repos/ontohub/ontohub-backend/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ontohub/ontohub-backend/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ontohub/ontohub-backend/tags',
#       'blobs_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ontohub/ontohub-backend/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ontohub/ontohub-backend/languages',
#       'stargazers_url': 'https://api.github.com/repos/ontohub/ontohub-backend/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ontohub/ontohub-backend/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ontohub/ontohub-backend/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ontohub/ontohub-backend/subscription',
#       'commits_url': 'https://api.github.com/repos/ontohub/ontohub-backend/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ontohub/ontohub-backend/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ontohub/ontohub-backend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ontohub/ontohub-backend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ontohub/ontohub-backend/merges',
#       'archive_url': 'https://api.github.com/repos/ontohub/ontohub-backend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ontohub/ontohub-backend/downloads',
#       'issues_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ontohub/ontohub-backend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ontohub/ontohub-backend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ontohub/ontohub-backend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ontohub/ontohub-backend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ontohub/ontohub-backend/deployments',
#       'created_at': '2016-08-29T09:04:36Z',
#       'updated_at': '2019-11-08T16:24:03Z',
#       'pushed_at': '2019-11-29T05:19:49Z',
#       'git_url': 'git://github.com/ontohub/ontohub-backend.git',
#       'ssh_url': 'git@github.com:ontohub/ontohub-backend.git',
#       'clone_url': 'https://github.com/ontohub/ontohub-backend.git',
#       'svn_url': 'https://github.com/ontohub/ontohub-backend',
#       'homepage': '',
#       'size': 1311,
#       'stargazers_count': 15,
#       'watchers_count': 15,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 32,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'forks': 1,
#       'open_issues': 32,
#       'watchers': 15,
#       'default_branch': 'master'}},
#     'base': {'label': 'ontohub:master',
#      'ref': 'master',
#      'sha': 'adfe0b69a8c6abc25aba197e87239f4d3d991393',
#      'user': {'login': 'ontohub',
#       'id': 1575984,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1NzU5ODQ=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1575984?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ontohub',
#       'html_url': 'https://github.com/ontohub',
#       'followers_url': 'https://api.github.com/users/ontohub/followers',
#       'following_url': 'https://api.github.com/users/ontohub/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ontohub/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ontohub/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ontohub/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ontohub/orgs',
#       'repos_url': 'https://api.github.com/users/ontohub/repos',
#       'events_url': 'https://api.github.com/users/ontohub/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ontohub/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 66828339,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2NjgyODMzOQ==',
#       'name': 'ontohub-backend',
#       'full_name': 'ontohub/ontohub-backend',
#       'private': False,
#       'owner': {'login': 'ontohub',
#        'id': 1575984,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1NzU5ODQ=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/1575984?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ontohub',
#        'html_url': 'https://github.com/ontohub',
#        'followers_url': 'https://api.github.com/users/ontohub/followers',
#        'following_url': 'https://api.github.com/users/ontohub/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ontohub/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ontohub/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ontohub/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ontohub/orgs',
#        'repos_url': 'https://api.github.com/users/ontohub/repos',
#        'events_url': 'https://api.github.com/users/ontohub/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ontohub/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ontohub/ontohub-backend',
#       'description': 'The main Ontohub service that serves the data for the frontend and other clients via the GraphQL API.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ontohub/ontohub-backend',
#       'forks_url': 'https://api.github.com/repos/ontohub/ontohub-backend/forks',
#       'keys_url': 'https://api.github.com/repos/ontohub/ontohub-backend/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ontohub/ontohub-backend/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ontohub/ontohub-backend/teams',
#       'hooks_url': 'https://api.github.com/repos/ontohub/ontohub-backend/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ontohub/ontohub-backend/events',
#       'assignees_url': 'https://api.github.com/repos/ontohub/ontohub-backend/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ontohub/ontohub-backend/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ontohub/ontohub-backend/tags',
#       'blobs_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ontohub/ontohub-backend/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ontohub/ontohub-backend/languages',
#       'stargazers_url': 'https://api.github.com/repos/ontohub/ontohub-backend/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ontohub/ontohub-backend/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ontohub/ontohub-backend/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ontohub/ontohub-backend/subscription',
#       'commits_url': 'https://api.github.com/repos/ontohub/ontohub-backend/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ontohub/ontohub-backend/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ontohub/ontohub-backend/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ontohub/ontohub-backend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ontohub/ontohub-backend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ontohub/ontohub-backend/merges',
#       'archive_url': 'https://api.github.com/repos/ontohub/ontohub-backend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ontohub/ontohub-backend/downloads',
#       'issues_url': 'https://api.github.com/repos/ontohub/ontohub-backend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ontohub/ontohub-backend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ontohub/ontohub-backend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ontohub/ontohub-backend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ontohub/ontohub-backend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ontohub/ontohub-backend/deployments',
#       'created_at': '2016-08-29T09:04:36Z',
#       'updated_at': '2019-11-08T16:24:03Z',
#       'pushed_at': '2019-11-29T05:19:49Z',
#       'git_url': 'git://github.com/ontohub/ontohub-backend.git',
#       'ssh_url': 'git@github.com:ontohub/ontohub-backend.git',
#       'clone_url': 'https://github.com/ontohub/ontohub-backend.git',
#       'svn_url': 'https://github.com/ontohub/ontohub-backend',
#       'homepage': '',
#       'size': 1311,
#       'stargazers_count': 15,
#       'watchers_count': 15,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 32,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'forks': 1,
#       'open_issues': 32,
#       'watchers': 15,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/560'},
#      'html': {'href': 'https://github.com/ontohub/ontohub-backend/pull/560'},
#      'issue': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/560'},
#      'comments': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/issues/560/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/560/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/pulls/560/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ontohub/ontohub-backend/statuses/91151abebd6a321fb71b2fd039cebd9e1635e504'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 2,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 10,
#     'deletions': 12,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z',
#   'org': {'id': 1575984,
#    'login': 'ontohub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ontohub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1575984?'}},
#  {'id': '10973322397',
#   'type': 'ForkEvent',
#   'actor': {'id': 40690061,
#    'login': 'jtpils',
#    'display_login': 'jtpils',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jtpils',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40690061?'},
#   'repo': {'id': 180148562,
#    'name': 'pointcloudlearning/3D-Deep-Learning-Paper-List',
#    'url': 'https://api.github.com/repos/pointcloudlearning/3D-Deep-Learning-Paper-List'},
#   'payload': {'forkee': {'id': 224781818,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ3ODE4MTg=',
#     'name': '3D-Deep-Learning-Paper-List',
#     'full_name': 'jtpils/3D-Deep-Learning-Paper-List',
#     'private': False,
#     'owner': {'login': 'jtpils',
#      'id': 40690061,
#      'node_id': 'MDQ6VXNlcjQwNjkwMDYx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/40690061?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jtpils',
#      'html_url': 'https://github.com/jtpils',
#      'followers_url': 'https://api.github.com/users/jtpils/followers',
#      'following_url': 'https://api.github.com/users/jtpils/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jtpils/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jtpils/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jtpils/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jtpils/orgs',
#      'repos_url': 'https://api.github.com/users/jtpils/repos',
#      'events_url': 'https://api.github.com/users/jtpils/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jtpils/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/jtpils/3D-Deep-Learning-Paper-List',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List',
#     'forks_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/forks',
#     'keys_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/teams',
#     'hooks_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/hooks',
#     'issue_events_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/events',
#     'assignees_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/tags',
#     'blobs_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/languages',
#     'stargazers_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/stargazers',
#     'contributors_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/contributors',
#     'subscribers_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/subscribers',
#     'subscription_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/subscription',
#     'commits_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/merges',
#     'archive_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/downloads',
#     'issues_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/jtpils/3D-Deep-Learning-Paper-List/deployments',
#     'created_at': '2019-11-29T05:19:51Z',
#     'updated_at': '2019-11-29T05:14:10Z',
#     'pushed_at': '2019-04-21T01:26:29Z',
#     'git_url': 'git://github.com/jtpils/3D-Deep-Learning-Paper-List.git',
#     'ssh_url': 'git@github.com:jtpils/3D-Deep-Learning-Paper-List.git',
#     'clone_url': 'https://github.com/jtpils/3D-Deep-Learning-Paper-List.git',
#     'svn_url': 'https://github.com/jtpils/3D-Deep-Learning-Paper-List',
#     'homepage': None,
#     'size': 48,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z',
#   'org': {'id': 49400839,
#    'login': 'pointcloudlearning',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pointcloudlearning',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49400839?'}},
#  {'id': '10973322394',
#   'type': 'PushEvent',
#   'actor': {'id': 16324905,
#    'login': 'JoanGarciaCedano',
#    'display_login': 'JoanGarciaCedano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JoanGarciaCedano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16324905?'},
#   'repo': {'id': 220303948,
#    'name': 'JoanGarciaCedano/Curso-Javascript',
#    'url': 'https://api.github.com/repos/JoanGarciaCedano/Curso-Javascript'},
#   'payload': {'push_id': 4334428010,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3516618e09c9c47d5c7c93671f05d83599bd581f',
#    'before': '150e41e274e39224ae32ac0177525f03f5fcc5f9',
#    'commits': [{'sha': '3516618e09c9c47d5c7c93671f05d83599bd581f',
#      'author': {'email': 'joan.gc.mail@gmail.com', 'name': 'JoanGarciaCedano'},
#      'message': 'The spread operator',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JoanGarciaCedano/Curso-Javascript/commits/3516618e09c9c47d5c7c93671f05d83599bd581f'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:52Z'},
#  {'id': '10973322387',
#   'type': 'WatchEvent',
#   'actor': {'id': 2222041,
#    'login': 'jackyglony',
#    'display_login': 'jackyglony',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jackyglony',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2222041?'},
#   'repo': {'id': 198421942,
#    'name': 'Hardik8184/ClickShrinkEffect',
#    'url': 'https://api.github.com/repos/Hardik8184/ClickShrinkEffect'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:51Z'},
#  {'id': '10973322378',
#   'type': 'PushEvent',
#   'actor': {'id': 8714775,
#    'login': 'ntwcklng',
#    'display_login': 'ntwcklng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ntwcklng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8714775?'},
#   'repo': {'id': 32723844,
#    'name': 'ntwcklng/gb',
#    'url': 'https://api.github.com/repos/ntwcklng/gb'},
#   'payload': {'push_id': 4334427998,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '56963d541b3bbca82861fa8fff49a0564aa0afa9',
#    'before': '472a26b572cbb15af9ba17997d34b58edf39e2d5',
#    'commits': [{'sha': '56963d541b3bbca82861fa8fff49a0564aa0afa9',
#      'author': {'email': 'ntwcklng@gmail.com', 'name': 'ntwcklng'},
#      'message': 'update logo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ntwcklng/gb/commits/56963d541b3bbca82861fa8fff49a0564aa0afa9'}]},
#   'public': True,
#   'created_at': '2019-11-29T05:19:51Z'},
#  {'id': '10973322380',
#   'type': 'PushEvent',
#   'actor': {'id': 25180681,
#    'login': 'renovate-bot',
#    'display_login': 'renovate-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#   'repo': {'id': 198908178,
#    'name': 'renovate-bot/nodejs-datastore-session',
#    'url': 'https://api.github.com/repos/renovate-bot/nodejs-datastore-session'},
#   'payload': {'push_id': 4334427997,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '0ca10ebd65183f2220bf9e0ea93622ac0860e674',
#    'before': '0ca10ebd65183f2220bf9e0ea93622ac0860e674',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-29T05:19:51Z'},
#  {'id': '10973322384',
#   'type': 'CreateEvent',
#   'actor': {'id': 8960313,
#    'login': 'halfopen',
#    'display_login': 'halfopen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/halfopen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8960313?'},
#   'repo': {'id': 204376520,
#    'name': 'halfopen/GraduationThesis',
#    'url': 'https://api.github.com/repos/halfopen/GraduationThesis'},
#   'payload': {'ref': 'overleaf-2019-11-29-0519',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T05:19:51Z'}]

# %%
type(json.loads(r.text))
# Out:
# list

# %%
type(r.text)
# Out:
# str

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
import requests
import json
payload={'key1':'value1','key2':'value2'}
r=requests.get('https://cat-fact.herokuapp.com/facts',params=payload)

json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r.text
# Out:
# '[{"id":"10973322494","type":"PushEvent","actor":{"id":51776310,"login":"TangBii","display_login":"TangBii","gravatar_id":"","url":"https://api.github.com/users/TangBii","avatar_url":"https://avatars.githubusercontent.com/u/51776310?"},"repo":{"id":224410445,"name":"TangBii/TangBii.github.io","url":"https://api.github.com/repos/TangBii/TangBii.github.io"},"payload":{"push_id":4334428067,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"869665295c975434b82805d44a2377f2a5db9fd8","before":"361ea82333e26c064f7e52ac544f0bcde6f390c2","commits":[{"sha":"869665295c975434b82805d44a2377f2a5db9fd8","author":{"email":"601098499@qq.com","name":"TangBii"},"message":"Site updated: 2019-11-29 13:19:47","distinct":true,"url":"https://api.github.com/repos/TangBii/TangBii.github.io/commits/869665295c975434b82805d44a2377f2a5db9fd8"}]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322490","type":"PushEvent","actor":{"id":25004868,"login":"const-k","display_login":"const-k","gravatar_id":"","url":"https://api.github.com/users/const-k","avatar_url":"https://avatars.githubusercontent.com/u/25004868?"},"repo":{"id":219404596,"name":"const-k/simple-maven-project-with-tests","url":"https://api.github.com/repos/const-k/simple-maven-project-with-tests"},"payload":{"push_id":4334428065,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a1507718d1263038112fcbb4c6870b6fba546a48","before":"b3a39b21ac048d9298986e0d4a1d9f4dd185df8f","commits":[{"sha":"a1507718d1263038112fcbb4c6870b6fba546a48","author":{"email":"kss07120@gmail.com","name":"const-k"},"message":"Update Jenkinsfile","distinct":true,"url":"https://api.github.com/repos/const-k/simple-maven-project-with-tests/commits/a1507718d1263038112fcbb4c6870b6fba546a48"}]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322485","type":"CreateEvent","actor":{"id":58320520,"login":"gageiscool","display_login":"gageiscool","gravatar_id":"","url":"https://api.github.com/users/gageiscool","avatar_url":"https://avatars.githubusercontent.com/u/58320520?"},"repo":{"id":224781819,"name":"gageiscool/Gage","url":"https://api.github.com/repos/gageiscool/Gage"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322486","type":"PushEvent","actor":{"id":56465314,"login":"Jack-genius","display_login":"Jack-genius","gravatar_id":"","url":"https://api.github.com/users/Jack-genius","avatar_url":"https://avatars.githubusercontent.com/u/56465314?"},"repo":{"id":215474703,"name":"Jack-genius/jack-genius.github.io","url":"https://api.github.com/repos/Jack-genius/jack-genius.github.io"},"payload":{"push_id":4334428063,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e4e914ab4ef8a5691abcb9a50b1111a59515e32d","before":"6f95fde96e2907c5947da05476386ef73f309b0f","commits":[{"sha":"e4e914ab4ef8a5691abcb9a50b1111a59515e32d","author":{"email":"56465314+Jack-genius@users.noreply.github.com","name":"Jack-genius"},"message":"Update 2019-10-15-排个座次？.md","distinct":true,"url":"https://api.github.com/repos/Jack-genius/jack-genius.github.io/commits/e4e914ab4ef8a5691abcb9a50b1111a59515e32d"}]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322487","type":"PushEvent","actor":{"id":25180681,"login":"renovate-bot","display_login":"renovate-bot","gravatar_id":"","url":"https://api.github.com/users/renovate-bot","avatar_url":"https://avatars.githubusercontent.com/u/25180681?"},"repo":{"id":211969970,"name":"renovate-bot/java-translate","url":"https://api.github.com/repos/renovate-bot/java-translate"},"payload":{"push_id":4334428055,"size":0,"distinct_size":0,"ref":"refs/heads/master","head":"4a30c3ebb72f447c13b9b4cbaf3ea4737a4844d3","before":"4a30c3ebb72f447c13b9b4cbaf3ea4737a4844d3","commits":[]},"public":true,"created_at":"2019-11-29T05:19:53Z"},{"id":"10973322482","type":"DeleteEvent","actor":{"id":8960313,"login":"halfopen","display_login":"halfopen ...
