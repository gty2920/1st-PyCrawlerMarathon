# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time


browser = webdriver.Chrome('./chromedriver.exe')
browser.get('https://www.cupoy.com/newsfeed/topstory')
time.sleep(5)

SCROLL_PAUSE_TIME = 3
c=[]
a = []
n = 1
while n<500:
    html=browser.page_source
    soup=BeautifulSoup(html,'html5lib')
    last_height = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    for i in soup.find('div', class_ = 'ReactVirtualized__Grid__innerScrollContainer'):
        
        c=i.find(class_ = 'sc-gacfCG bPSpUf').text
        title=i.find(class_ = 'sc-erNlkL sc-ekulBa hDLssh').text
        a.append(title)
        print(n,c,title)    
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
        if n==500:
            break 
        n+=1
        new_height = browser.execute_script("return document.body.scrollHeight")
        last_height = new_height
   
browser.quit()
# Out:
# 1 科技 科學家再證實廣義相對論預言，時空於白矮星周圍扭曲 | TechNews 科技新報
# 2 科技 商業化之路過於漫長，Alphabet 宣佈中止 Makani 風箏發電計畫 | TechNews 科技新報
# 3 科技 野火致碳庫存銳減，澳洲恐需斥  210  億元挽救 | TechNews 科技新報
# 4 科技 一手打造口罩地圖，揭露「鍵盤救國」的幕後團隊 | TechNews 科技新報
# 5 科技 鯨魚壓力有多大，看「耳垢」就知道 | TechNews 科技新報
# 6 手機平板 三星南韓工廠確認武漢肺炎病例，手機生產緊急叫停 | TechNews 科技新報
# 7 Engadget 《Minecraft Earth》將提供可以與手機互動的 NFC 玩偶
# 8 遊戲情報 打電動就能坐擁百萬粉絲！一探電玩 KOL 影響力排名！ | dcplus 數位行銷實戰家
# 9 科技 疫情蔓延現「逃離中國潮」！臺幹被逼復工無奈「工作可以再找，命只有一條」 | TechNews 科技新報
# 10 Engadget Bethesda 也離開了 GeForce Now 串流服務
# 11 The News Lens 關鍵評論網 【東南亞週報】中國—東協特別外長會議寮國落幕｜泰槍擊案頻傳輿論聚焦槍枝管制｜馬哈迪APEC結束後再決定何時交棒 - The News Lens 關鍵評論網
# 12 The News Lens 關鍵評論網 武漢肺炎中東擴散：伊朗出現第6例死亡，伊拉克傳出現首例 - The News Lens 關鍵評論網
# 13 旅遊 武漢肺炎：23日再添2確診案例，伊朗、義大利旅遊疫情列為第一級，醫事人員不得出國 - The News Lens 關鍵評論網
# 14 The News Lens 關鍵評論網 拿到正式的offer後，還可以要求多一點薪水、股票或假期嗎？　 - The News Lens 關鍵評論網
# 15 科技 科學家再證實廣義相對論預言，時空於白矮星周圍扭曲 | TechNews 科技新報
# 16 科技 商業化之路過於漫長，Alphabet 宣佈中止 Makani 風箏發電計畫 | TechNews 科技新報
# 17 科技 野火致碳庫存銳減，澳洲恐需斥  210  億元挽救 | TechNews 科技新報
# ...
